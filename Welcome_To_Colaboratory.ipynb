# %% [markdown]
# <a href="https://colab.research.google.com/github/T-Vikas/AI/blob/master/Welcome_To_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("CGB_-_Consumer_Complaints_Data.csv")

# %%
data
# Out:
#         Ticket ID          Ticket Created Date Created Date of Issue  \
# 0         4923410  07/26/2021 09:59:38 PM   07/26/2021           NaN
# 1         4947156  08/06/2021 07:56:45 PM   08/06/2021           NaN
# 2         4957510  08/12/2021 05:38:25 PM   08/12/2021    08/12/2021
# 3         5396122  04/02/2022 04:01:34 PM   04/02/2022    03/25/2022
# 4         4917724  07/23/2021 02:50:59 AM   07/23/2021           NaN
# ...           ...                     ...          ...           ...
# 197853    5195547  12/16/2021 05:49:23 PM   12/16/2021           NaN
# 197854    5194884  12/16/2021 12:02:38 PM   12/16/2021           NaN
# 197855    5342730  03/09/2022 04:45:14 PM   03/09/2022           NaN
# 197856    5335621  03/04/2022 11:06:58 PM   03/04/2022    03/04/2022
# 197857          5                     NaN          NaN           NaN
#
#        Time of Issue      Form                                     Method  \
# ...

# %%
data
# Out:
#         Ticket ID          Ticket Created Date Created Date of Issue  \
# 0         4923410  07/26/2021 09:59:38 PM   07/26/2021           NaN
# 1         4947156  08/06/2021 07:56:45 PM   08/06/2021           NaN
# 2         4957510  08/12/2021 05:38:25 PM   08/12/2021    08/12/2021
# 3         5396122  04/02/2022 04:01:34 PM   04/02/2022    03/25/2022
# 4         4917724  07/23/2021 02:50:59 AM   07/23/2021           NaN
# ...           ...                     ...          ...           ...
# 197853    5195547  12/16/2021 05:49:23 PM   12/16/2021           NaN
# 197854    5194884  12/16/2021 12:02:38 PM   12/16/2021           NaN
# 197855    5342730  03/09/2022 04:45:14 PM   03/09/2022           NaN
# 197856    5335621  03/04/2022 11:06:58 PM   03/04/2022    03/04/2022
# 197857          5                     NaN          NaN           NaN
#
#        Time of Issue      Form                                     Method  \
# ...

# %%
data.columns
# Out:
# Index(['Ticket ID', 'Ticket Created', 'Date Created', 'Date of Issue',
#        'Time of Issue', 'Form', 'Method', 'Issue', 'Caller ID Number',
#        'Type of Call or Messge', 'Advertiser Business Number', 'City', 'State',
#        'Zip', 'Location (Center point of the Zip Code)',
#        'Type of Property Goods or Services'],
#       dtype='object')

# %%
data_tv=data[data.Form == "TV"]

# %%
data_tv
# Out:
#         Ticket ID          Ticket Created Date Created Date of Issue  \
# 0         4923410  07/26/2021 09:59:38 PM   07/26/2021           NaN
# 17        5396394  04/02/2022 07:17:51 PM   04/02/2022    04/02/2022
# 21        5396605  04/02/2022 09:46:38 PM   04/02/2022           NaN
# 23        5396944  04/03/2022 02:51:35 AM   04/03/2022    03/27/2022
# 28        5206147  12/23/2021 10:48:41 AM   12/23/2021           NaN
# ...           ...                     ...          ...           ...
# 197784    5465750  05/08/2022 05:39:05 AM   05/08/2022           NaN
# 197798    5495879  05/24/2022 07:29:00 AM   05/24/2022    05/22/2022
# 197827    5195708  12/16/2021 06:37:12 PM   12/16/2021           NaN
# 197847    5194890  12/16/2021 12:25:03 PM   12/16/2021           NaN
# 197849    5465723  05/08/2022 04:04:08 AM   05/08/2022           NaN
#
#        Time of Issue Form     Method             Issue Caller ID Number  \
# ...

# %%
data_tv.dropna(inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
data["Type of Property Goods or Services"].unique()
# Out:
# array(['None', 'unknown_services', 'Health Insurance Services',
#        'Prizes Won Something Services', 'Student Loans Services',
#        'Home Improvement Services', 'Amazon Services', 'Unknown Services',
#        'other_services', 'Other Services', 'Auto Warranty Services',
#        'Credit Card Interest Rates Services', 'Solar Panels Services',
#        'Medical Devices Services', 'auto_warranty_services',
#        'solar_panels_services', 'Computer Tech Support Services',
#        'medicare_medicaid_services', 'Mortgage Loans Services',
#        'Pay Day Loans Services', 'Political Services',
#        'Prescription Medicines Services', 'Medicare Medicaid Services',
#        'Credit Card Debt Services', 'Google Listings Services',
#        'Legal Actions Services', 'amazon_services',
#        'mortgage_loans_services', 'Home Security Alarms Services',
#        'Irs Services', 'credit_card_interest_rates_services',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197858 entries, 0 to 197857
# Data columns (total 16 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   Ticket ID                                197858 non-null  int64
#  1   Ticket Created                           197857 non-null  object
#  2   Date Created                             197857 non-null  object
#  3   Date of Issue                            105504 non-null  object
#  4   Time of Issue                            96877 non-null   object
#  5   Form                                     197857 non-null  object
#  6   Method                                   188207 non-null  object
#  7   Issue                                    196501 non-null  object
#  8   Caller ID Number                         197806 non-null  object
#  9   Type of Call or Messge                   72076 non-null   object
# ...
